# %% [markdown]
# # Data Source Check
# Th purpose of this notebook is to do a lightweight exploration of any of the datasets within the SafeGraph project. If there's an issue with loading in the dataset into the SQL database, then you can explore that issue in here. (This of it as a scratchbook)

# %%
# import statements
import pandas as pd

# %% [markdown]
# #### ---- Update Date: 12/02/2020 ----

# %%
new_data = pd.read_csv('//sandag.org/home/shared/Technical Services/EDAM/SafeGraph_COVID19/v2/main-file/2020-01-13-weekly-patterns-fixed.csv', nrows=100)
new_data.head()
# Out:
#                     safegraph_place_id                        location_name  \
# 0  sg:0013bd02b3564a9187a52f8e2799233e          Small Business Transactions
# 1  sg:001955fa1c994b4c8c877316a66dd986                           McDonald's
# 2  sg:001e39c6b18645a5950b13a278b242c3                         Peking House
# 3  sg:0021f605c7904ed2a3f7bd28d6c40844                 ATI Physical Therapy
# 4  sg:0023804ee36c4056886ef54e5a0cb773  American Express Financial Advisors
#
#                   street_address         city region  postal_code  \
# 0  1007 Mill Crescent Pl Ste 274    Arlington     TX        76006
# 1               1134 280 By Pass  Phenix City     AL        36867
# 2               9617 Liberty Ave   Ozone Park     NY        11417
# 3         1111 E 87th St Ste 600      Chicago     IL        60619
# 4        4210 Metro Pkwy Ste 230   Fort Myers     FL        33916
#
#   iso_country_code                        safegraph_brand_ids  \
# ...

# %%
new_data.columns
# Out:
# Index(['safegraph_place_id', 'location_name', 'street_address', 'city',
#        'region', 'postal_code', 'iso_country_code', 'safegraph_brand_ids',
#        'brands', 'date_range_start', 'date_range_end', 'raw_visit_counts',
#        'raw_visitor_counts', 'visits_by_day', 'visits_by_each_hour', 'poi_cbg',
#        'visitor_home_cbgs', 'visitor_daytime_cbgs',
#        'visitor_country_of_origin', 'distance_from_home', 'median_dwell',
#        'bucketed_dwell_times', 'related_same_day_brand',
#        'related_same_week_brand', 'device_type'],
#       dtype='object')

# %%
old_data = pd.read_csv('//sandag.org/home/shared/Technical Services/EDAM/SafeGraph_COVID19/v2/main-file/2020-12-02-weekly-patterns-part1.csv', nrows=100)
old_data.head()
# Out:
#               placekey                   safegraph_place_id  \
# 0  226-223@8fc-8ct-cnq  sg:00011ea2089a4795874f987b8ae534fe
# 1  222-222@5z7-z4p-52k  sg:00035ee2a75e41c7a6fe143a7f1895e9
# 2  zzw-223@646-9rk-nqz  sg:00083de836884deeae33d8f5aa622049
# 3  zzy-222@8dj-gdv-5fz  sg:0009738f1e8f43aabbe5a18cc249ade6
# 4  zzy-222@8gm-r4c-qzz  sg:0009e0fc0cb84885a115381d73635118
#
#                               location_name        street_address  \
# 0                          Oriental Gourmet         8456 Gulf Fwy
# 1                                  BV Grill  10256 Golf Course Rd
# 2                             Cash & Dash 7     701 Highway 701 N
# 3                      Mahalos Sweet Ice Co     400 Trillium Blvd
# 4  Geraldine Convenient Storage Al Hwy 75 N   41758 AL Highway 75
#
#           city region  postal_code iso_country_code safegraph_brand_ids  \
# 0      Houston     TX        77017               US                 NaN
# ...

# %%
old_data.columns
# Out:
# Index(['placekey', 'safegraph_place_id', 'location_name', 'street_address',
#        'city', 'region', 'postal_code', 'iso_country_code',
#        'safegraph_brand_ids', 'brands', 'date_range_start', 'date_range_end',
#        'raw_visit_counts', 'raw_visitor_counts', 'visits_by_day',
#        'visits_by_each_hour', 'poi_cbg', 'visitor_home_cbgs',
#        'visitor_daytime_cbgs', 'visitor_country_of_origin',
#        'distance_from_home', 'median_dwell', 'bucketed_dwell_times',
#        'related_same_day_brand', 'related_same_week_brand', 'device_type'],
#       dtype='object')

# %%
print(new_data.info())
print(old_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   safegraph_place_id         100 non-null    object
#  1   location_name              100 non-null    object
#  2   street_address             100 non-null    object
#  3   city                       100 non-null    object
#  4   region                     100 non-null    object
#  5   postal_code                100 non-null    int64
#  6   iso_country_code           100 non-null    object
#  7   safegraph_brand_ids        33 non-null     object
#  8   brands                     33 non-null     object
#  9   date_range_start           100 non-null    object
#  10  date_range_end             100 non-null    object
#  11  raw_visit_counts           100 non-null    int64
#  12  raw_visitor_counts         100 non-null    int64
# ...

# %%
# check if there are any new columns between the data --> in this case, no
for col_names in new_data.columns:
    if col_names not in old_data.columns:
        print(col_names)

# %%
# visually the device type rows are the same as well (showed that there was an error here when loading into SQL database)
display(new_data['device_type'])
display(old_data['device_type'])
# Out:
# 0       {"android":24,"ios":14}
# 1     {"android":177,"ios":109}
# 2       {"android":43,"ios":36}
# 3         {"android":0,"ios":0}
# 4       {"android":23,"ios":10}
#                 ...
# 95        {"android":0,"ios":4}
# 96       {"android":14,"ios":5}
# 97       {"android":11,"ios":5}
# 98       {"android":15,"ios":7}
# 99      {"android":88,"ios":35}
# Name: device_type, Length: 100, dtype: object
# 0     {"android":27,"ios":6}
# 1      {"android":9,"ios":6}
# 2      {"android":4,"ios":4}
# 3      {"android":4,"ios":4}
# 4      {"android":4,"ios":4}
#                ...
# 95    {"android":8,"ios":21}
# 96     {"android":0,"ios":0}
# 97    {"android":4,"ios":23}
# 98     {"android":0,"ios":0}
# 99     {"android":6,"ios":5}
# Name: device_type, Length: 100, dtype: object
